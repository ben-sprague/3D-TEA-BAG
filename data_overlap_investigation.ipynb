# %%
import numpy as np

from datatools.DOT.DataServer import DataServer

# %%
sat_data = DataServer("/Users/ben/Desktop/3D-TEA-BAG/data/CPOM_DOT.nc", "/Users/ben/Desktop/3D-TEA-BAG/data/Full_DOT_data_Arco_2025_09.nc")

# %%
sat_data.get(time = np.datetime64('2013-09-01'), lat = 70.5, lon = -140, priority='new')
# Out:
# ([np.float64(-0.7624653704327157)],
#  [np.float64(0.01053883371344162)],
#  [np.float64(-0.023077560412001503)])

# %%
print(sat_data.start_time)
print(sat_data.overlap_start_time)
print(sat_data.overlap_end_time)
print(sat_data.end_time)
# Out:
# <xarray.DataArray 'time' ()> Size: 8B
# array('2003-01-01T00:00:00.000000', dtype='datetime64[us]')
# <xarray.DataArray 'time' ()> Size: 8B
# array('2011-01-01T00:00:00.000000', dtype='datetime64[us]')
# <xarray.DataArray 'time' ()> Size: 8B
# array('2014-12-01T00:00:00.000000', dtype='datetime64[us]')
# <xarray.DataArray 'time' ()> Size: 8B
# array('2025-09-01T00:00:00.000000', dtype='datetime64[us]')
